# %% [markdown]
# <a href="https://colab.research.google.com/github/Fotters05/-/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Цель работы заключается в том, что нам нужно реализовать базовый анализ датасета

# %%
import pandas as pd
import numpy as np

netflix = pd.read_csv("netflix_titles.csv")

netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Далее был выведен весь датасет с фильмами.

# %%
print(netflix.shape)
# Out:
# (8807, 12)

# %% [markdown]
# Затем была выведена размерность массива

# %%
print(netflix.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 'id фильмов', 'тип', 'название', 'режиссер', 'актерский состав', 'страна', 'дата выхода',
# 'год релиза', 'рейтинг', 'продолжительность', 'тематика', 'описание

# %%
netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# После чего, были выведены все уникальные значения.

# %%
netflix.sort_values(by='show_id')
# Out:
#      show_id     type                                  title  \
# 0         s1    Movie                   Dick Johnson Is Dead
# 9        s10    Movie                           The Starling
# 99      s100  TV Show                           On the Verge
# 999    s1000    Movie                               Stowaway
# 1000   s1001    Movie                               Wild Dog
# ...      ...      ...                                    ...
# 994     s995    Movie                  This Lady Called Life
# 995     s996    Movie                              Vizontele
# 996     s997    Movie                             HOMUNCULUS
# 997     s998  TV Show  Life in Color with David Attenborough
# 998     s999    Movie                   Searching For Sheela
#
#                               director  \
# 0                      Kirsten Johnson
# 9                       Theodore Melfi
# 99                                 NaN
# 999                          Joe Penna
# ...

# %% [markdown]
# Далее была произведена сортировка по определенным параметрам.

# %%
netflix.drop(columns = ["description"])
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Был удален столбец "description".

# %%
netflix = netflix.replace(np.nan, "N/A")

# %% [markdown]
# Потом были заменены определенные значения в датасете.

# %%
netflix.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Затем были удалены ненужные данные, а конкретнее дубликаты.

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Далее был проведен анализ с помощью функции info.

# %%
netflix.describe
# Out:
# <bound method NDFrame.describe of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              N/A
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              N/A
# 4         s5  TV Show           Kota Factory              N/A
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              N/A
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   N/A  United States
# ...

# %% [markdown]
# После чего был проведен анализ с помощью функций descride.

# %%
selected_data = netflix.loc[0:5, ["show_id", "type", "title", "director", "cast"]]
print(selected_data)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              N/A
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              N/A
# 4      s5  TV Show           Kota Factory              N/A
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast
# 0                                                N/A
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                N/A
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...

# %% [markdown]
# Далее была проведена выборка данных по строкам и столбцам с помощью loc.

# %%
netflix.to_csv("netflix_clear.csv")

# %% [markdown]
# Далее новый датасет был созранен.

# %% [markdown]
# Вывод: Удалось удачно поработать с датасетом, произвести различные действия с ним.
